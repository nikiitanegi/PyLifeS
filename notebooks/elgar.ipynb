# %%
import pandas as pd
df = pd.read_csv('../datasets/elgar_appendix.csv')

# %%
df
# Out:
#                          Taxon      Habitat           Diet  weight (g)   BMR
# 0       Tachyglossus aculeatus  Terrestrial  Invertebrates      3410.0  0.17
# 1     Ornithorhynchus anatinus      Aquatic  Invertebrates       690.0  0.31
# 2          Marmosa microtarsus     Arboreal  Invertebrates        14.5  1.79
# 3        Didelphis marsupialis  Terrestrial     Omnivorous      1350.0  0.45
# 4             Planigale gilesi  Terrestrial  Invertebrates         9.4  1.40
# ..                         ...          ...            ...         ...   ...
# 260              Lepus timidus  Terrestrial          Grass      3004.0  0.36
# 261       Sylvilagus audubonii  Terrestrial          Grass       702.0  0.63
# 262      Elephantulus edwardii  Terrestrial  Invertebrates        50.0  1.09
# 263     Elephantulus rugescens  Terrestrial  Invertebrates        53.0  1.07
# 264  Petrodromus tetradactylus  Terrestrial  Invertebrates       210.0  0.61
#
# [265 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('../datasets/elgar_appendix.csv')

# Create scatter plot
weight_column = 'weight (g)'
bmr_column = 'BMR'

plt.scatter(df[weight_column], df[bmr_column], alpha=0.5)
plt.title('Scatter Plot')
plt.xlabel('log of Weight (g)')
plt.ylabel('log of BMR')
plt.grid(True)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('../datasets/elgar_appendix.csv')

# Create scatter plot
weight_column = 'weight (g)'
bmr_column = 'BMR'

plt.scatter(df[weight_column], df[bmr_column], alpha=0.5)
plt.title('Scatter Plot')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('log of Weight (g)')
plt.ylabel('log of BMR')
plt.grid(True)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../datasets/elgar_appendix.csv')

weight_column = 'weight (g)'
bmr_column = 'BMR'

plt.plot(df[weight_column], df[bmr_column], marker='o')

plt.xlabel('weight (g)')
plt.ylabel('BMR')
plt.title(' Plot')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../datasets/elgar_appendix.csv')

weight_column = 'weight (g)'
bmr_column = 'BMR'

plt.plot(df[weight_column], df[bmr_column])
plt.xscale('log') 
plt.yscale('log') 
plt.xlabel('weight (g)')
plt.ylabel('BMR')
plt.title('Weight BMR Plot')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('../datasets/elgar_appendix.csv') 

weight_column = 'weight (g)'
bmr_column = 'BMR'

log_weight = np.log(df[weight_column])
log_bmr = np.log(df[bmr_column])

plt.scatter(log_weight, log_bmr, alpha=0.5)
plt.title('Scatter Plot of Log(Weight) vs. Log(BMR)')
plt.xlabel('Log of Weight (grams)')
plt.ylabel('Log of BMR')
plt.grid(True)
plt.show()
